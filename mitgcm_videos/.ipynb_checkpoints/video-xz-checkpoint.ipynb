# %%
# %reset
# %matplotlib inline
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
import scipy.io as sio
import netCDF4 as nc
import glob, os
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
import matplotlib.colors as mcolors
import xarray as xr
from mpl_toolkits.axes_grid1 import make_axes_locatable

#Creating red colormap
colors = plt.cm.Reds(np.linspace(0, 1, 256))
colors[0,:]=(1.0, 1.0, 1.0, 1.0)
Red = mcolors.LinearSegmentedColormap.from_list('colormap', colors)

# %%
# %cd /archive/eay/KaraSea_Simulations/Original2D
fileds = ['HR1.nc','HR2.nc','HR3.nc','HR4.nc','HR5.nc','HR6.nc']
filedtr= ['HRtracer1.nc','HRtracer2.nc','HRtracer3.nc','HRtracer4.nc','HRtracer5.nc','HRtracer6.nc']
ds = xr.open_mfdataset(fileds).sortby('T')
tr = xr.open_mfdataset(filedtr).sortby('T')
print(ds)
# Out:
# /arch8/eay/KaraSea_Simulations/Original2D
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/ipykernel/__main__.py:4: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# <xarray.Dataset>
# Dimensions:  (T: 246, X: 1280, Xp1: 1281, Y: 1, Yp1: 2, Z: 240, Zl: 240)
# Coordinates:
#   * Yp1      (Yp1) float64 0.0 200.0
#   * Z        (Z) float64 -3.299 -9.896 -16.49 ... -2.46e+03 -2.481e+03
#   * Zl       (Zl) float64 0.0 -6.597 -13.19 ... -2.427e+03 -2.449e+03 -2.471e+03
#   * Xp1      (Xp1) float64 -2.842e-14 56.24 112.5 ... 7.493e+04 7.5e+04
#   * X        (X) float64 28.12 84.36 140.6 ... 7.483e+04 7.49e+04 7.496e+04
#   * Y        (Y) float64 100.0
#   * T        (T) float64 0.0 2.16e+04 4.32e+04 ... 5.141e+06 5.162e+06 5.184e+06
# Data variables:
#     phi_nh   (T, Z, Y, X) float32 dask.array<chunksize=(41, 240, 1, 1280), meta=np.ndarray>
#     Temp     (T, Z, Y, X) float32 dask.array<chunksize=(41, 240, 1, 1280), meta=np.ndarray>
#     iter     (T) int32 dask.array<chunksize=(41,), meta=np.ndarray>
#     S        (T, Z, Y, X) float32 dask.array<chunksize=(41, 240, 1, 1280), meta=np.ndarray>
#     Eta      (T, Y, X) float32 dask.array<chunksize=(41, 1, 1280), meta=np.ndarray>
#     U        (T, Z, Y, Xp1) float32 dask.array<chunksize=(41, 240, 1, 1281), meta=np.ndarray>
#     W        (T, Zl, Y, X) float32 dask.array<chunksize=(41, 240, 1, 1280), meta=np.ndarray>
#     V        (T, Z, Yp1, X) float32 dask.array<chunksize=(41, 240, 2, 1280), meta=np.ndarray>
# Attributes:
#     build_date:      Tue Feb  7 16:52:43 EST 2017
#     build_user:      Elizabeth.Yankovsky
#     MITgcm_URL:      http://mitgcm.org
#     build_host:      gaea11
#     MITgcm_tag_id:   1.2234 2016/02/11
#     Nx:              1280
#     Ny:              1
#     sNx:             40
#     nPy:             1
#     nPx:             32
#     MITgcm_version:  checkpoint65t
#     OLx:             3
#     OLy:             3
#     Nr:              240
#     sNy:             1
#     MITgcm_mnc_ver:  0.9
#     nSx:             1
#     nSy:             1
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/ipykernel/__main__.py:5: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,

# %%
xq=ds['X']
zl=ds['Zl']
tracer = np.squeeze(tr.tracer)
salt = np.squeeze(ds.S)
u = np.squeeze(ds.U)
w = np.squeeze(ds.W)
v = np.squeeze(ds.V)
i=10 #time index
traceri=np.array(tracer[i,:,:])
traceri[traceri==0]=np.nan;

salti=np.array(salt[i,:,:]); 
mask=salti; mask[mask>0]=np.nan; mask[mask==0]=1.0

salti=np.array(salt[i,:,:]); 
salti[salti==0]=np.nan
print(salti)
# Out:
# [[      nan 34.726894 34.72017  ... 34.461464 34.461464 34.461464]
#  [      nan 34.67993  34.70718  ... 34.474407 34.474407 34.474407]
#  [      nan 34.686165 34.70249  ... 34.48731  34.48731  34.48731 ]
#  ...
#  [      nan       nan       nan ... 34.9139   34.9139   34.9139  ]
#  [      nan       nan       nan ... 34.9139   34.9139   34.9139  ]
#  [      nan       nan       nan ... 34.9139   34.9139   34.9139  ]]

# %%
# %cd /work/eay/mitgcm_videos/gif2D
#%rm *.png
# %ls
#%mkdir gif2D
# Out:
# /work2/eay/mitgcm_videos/gif2D
# index000.png  index039.png  index078.png  index117.png  index156.png
# index001.png  index040.png  index079.png  index118.png  index157.png
# index002.png  index041.png  index080.png  index119.png  index158.png
# index003.png  index042.png  index081.png  index120.png  index159.png
# index004.png  index043.png  index082.png  index121.png  index160.png
# index005.png  index044.png  index083.png  index122.png  index161.png
# index006.png  index045.png  index084.png  index123.png  index162.png
# index007.png  index046.png  index085.png  index124.png  index163.png
# index008.png  index047.png  index086.png  index125.png  index164.png
# index009.png  index048.png  index087.png  index126.png  index165.png
# index010.png  index049.png  index088.png  index127.png  index166.png
# index011.png  index050.png  index089.png  index128.png  index167.png
# index012.png  index051.png  index090.png  index129.png  index168.png
# index013.png  index052.png  index091.png  index130.png  index169.png
# index014.png  index053.png  index092.png  index131.png  index170.png
# index015.png  index054.png  index093.png  index132.png  index171.png
# index016.png  index055.png  index094.png  index133.png  index172.png
# index017.png  index056.png  index095.png  index134.png  index173.png
# index018.png  index057.png  index096.png  index135.png  index174.png
# index019.png  index058.png  index097.png  index136.png  index175.png
# index020.png  index059.png  index098.png  index137.png  index176.png
# index021.png  index060.png  index099.png  index138.png  index177.png
# index022.png  index061.png  index100.png  index139.png  index178.png
# index023.png  index062.png  index101.png  index140.png  index179.png
# index024.png  index063.png  index102.png  index141.png  index180.png
# index025.png  index064.png  index103.png  index142.png  index181.png
# index026.png  index065.png  index104.png  index143.png  index182.png
# index027.png  index066.png  index105.png  index144.png  index183.png
# index028.png  index067.png  index106.png  index145.png  index184.png
# index029.png  index068.png  index107.png  index146.png  index185.png
# index030.png  index069.png  index108.png  index147.png  index186.png
# index031.png  index070.png  index109.png  index148.png  index187.png
# index032.png  index071.png  index110.png  index149.png  index188.png
# index033.png  index072.png  index111.png  index150.png  index189.png
# index034.png  index073.png  index112.png  index151.png  index190.png
# index035.png  index074.png  index113.png  index152.png  index191.png
# index036.png  index075.png  index114.png  index153.png
# index037.png  index076.png  index115.png  index154.png
# index038.png  index077.png  index116.png  index155.png

# %%
# %cd /work/eay/mitgcm_videos/gif2D
#%rm *.png
#PLOTTING EXAMPLE
fig = plt.figure(figsize=(9, 7), dpi= 80, facecolor='w', edgecolor='k')
ax1 = fig.add_axes([0.15,0.1,0.7,0.7])  #left pos. bottom pos. width, height #ax1 = fig.add_subplot(111)
ax2 = fig.add_axes([.9, 0.1, 0.05, 0.7])
ax1.invert_yaxis

quad0= ax1.pcolormesh(xq/1000,zl,mask,cmap='Greys',vmin=0,vmax=2.)
quad1 = quad0
ax1.set_xlabel('X Position (km)',fontsize=16); ax1.set_ylabel('Depth (m)',fontsize=16)
ax1.tick_params(labelsize=16); ax2.tick_params(labelsize=12);

for i in range(240,241):
    traceri=np.array(tracer[i,:,:])
    traceri[traceri==0]=np.nan;
    quad1 = ax1.pcolormesh(xq/1000,zl,traceri,cmap=Red,vmin=0.0,vmax=1.0,shading='goaround')
    cb1 = fig.colorbar(quad1,ax2)
    ax1.set_title('Tracer concentration, day=%05.2f ' %(i/4.), fontsize=14)
    ax1.set_xlim(0,70)
    plt.savefig('index%.3d'%i)

# %%
# %cd /work/eay/mitgcm_videos/gif2D
#%rm *.png
fig = plt.figure(figsize=(9, 7), dpi= 80, facecolor='w', edgecolor='k')
ax1 = fig.add_axes([0.15,0.1,0.7,0.7])  #left pos. bottom pos. width, height #ax1 = fig.add_subplot(111)
ax2 = fig.add_axes([.87, 0.1, 0.05, 0.7])
ax1.invert_yaxis

quad0= ax1.pcolormesh(xq/1000,zl,mask,cmap='Greys',vmin=0,vmax=2.)
ax1.set_xlabel('X Position (km)',fontsize=16); ax1.set_ylabel('Depth (m)',fontsize=16)
ax1.tick_params(labelsize=16); ax2.tick_params(labelsize=12);

for i in range(220,245):
    ui=np.array(u[i,:,0:1280])
    ui[ui==0]=np.nan;
    quad1 = ax1.pcolormesh(xq/1000,zl,ui,cmap='RdBu_r',vmin=-0.02,vmax=0.02,shading='goaround')
    cb1 = fig.colorbar(quad1,ax2)
    ax1.set_title('Offshore velocity (u), day=%05.2f ' %(i/4.), fontsize=14)
    ax2.set_title('m/s', fontsize=14)
    ax1.set_xlim(0,70)
    plt.savefig('index%.3d'%i)
# Out:
# /work2/eay/mitgcm_videos/gif2D

# %%
# %cd /work/eay/mitgcm_videos/gif2D
#%rm *.png
fig = plt.figure(figsize=(9, 7), dpi= 80, facecolor='w', edgecolor='k')
ax1 = fig.add_axes([0.15,0.1,0.7,0.7])  #left pos. bottom pos. width, height #ax1 = fig.add_subplot(111)
ax2 = fig.add_axes([.87, 0.1, 0.05, 0.7])
ax1.invert_yaxis

quad0= ax1.pcolormesh(xq/1000,zl,mask,cmap='Greys',vmin=0,vmax=2.)
ax1.set_xlabel('X Position (km)',fontsize=16); ax1.set_ylabel('Depth (m)',fontsize=16)
ax1.tick_params(labelsize=16); ax2.tick_params(labelsize=10);

for i in range(223,245):
    wi=np.array(w[i,:,0:1280])
    wi[wi==0]=np.nan;
    quad1 = ax1.pcolormesh(xq/1000,zl,wi*1000,cmap='RdBu_r',vmin=-2,vmax=2,shading='goaround')
    cb1 = fig.colorbar(quad1,ax2,format='%.1fe-03')
    #quad1 = ax1.pcolormesh(xq/1000,zl,wi,cmap='RdBu_r',vmin=-.002,vmax=.002,shading='goaround')
    #cb1 = fig.colorbar(quad1,ax2,format='%.3e')
    
    ax1.set_xlim(0,70)
    ax1.set_title('Vertical velocity (w), day=%05.2f ' %(i/4.), fontsize=14)
    ax2.set_title('m/s', fontsize=14)
    plt.savefig('index%.3d'%i)
# Out:
# /work2/eay/mitgcm_videos/gif2D

# %%
from mpl_toolkits.axes_grid1 import AxesGrid

def shiftedColorMap(cmap, start=0, midpoint=0.5, stop=1.0, name='shiftedcmap'):
    '''
    Function to offset the "center" of a colormap. Useful for
    data with a negative min and positive max and you want the
    middle of the colormap's dynamic range to be at zero.

    Input
    -----
      cmap : The matplotlib colormap to be altered
      start : Offset from lowest point in the colormap's range.
          Defaults to 0.0 (no lower offset). Should be between
          0.0 and `midpoint`.
      midpoint : The new center of the colormap. Defaults to 
          0.5 (no shift). Should be between 0.0 and 1.0. In
          general, this should be  1 - vmax / (vmax + abs(vmin))
          For example if your data range from -15.0 to +5.0 and
          you want the center of the colormap at 0.0, `midpoint`
          should be set to  1 - 5/(5 + 15)) or 0.75
      stop : Offset from highest point in the colormap's range.
          Defaults to 1.0 (no upper offset). Should be between
          `midpoint` and 1.0.
    '''
    cdict = {
        'red': [],
        'green': [],
        'blue': [],
        'alpha': []
    }

    # regular index to compute the colors
    reg_index = np.linspace(start, stop, 257)

    # shifted index to match the data
    shift_index = np.hstack([
        np.linspace(0.0, midpoint, 128, endpoint=False), 
        np.linspace(midpoint, 1.0, 129, endpoint=True)
    ])

    for ri, si in zip(reg_index, shift_index):
        r, g, b, a = cmap(ri)

        cdict['red'].append((si, r, r))
        cdict['green'].append((si, g, g))
        cdict['blue'].append((si, b, b))
        cdict['alpha'].append((si, a, a))

    newcmap = matplotlib.colors.LinearSegmentedColormap(name, cdict)
    plt.register_cmap(cmap=newcmap)

    return newcmap

# %%
# %cd /work/eay/mitgcm_videos/gif2D
# %rm *.png
fig = plt.figure(figsize=(9, 7), dpi= 80, facecolor='w', edgecolor='k')
ax1 = fig.add_axes([0.15,0.1,0.7,0.7])  #left pos. bottom pos. width, height #ax1 = fig.add_subplot(111)
ax2 = fig.add_axes([.87, 0.1, 0.05, 0.7])
ax1.invert_yaxis

quad0= ax1.pcolormesh(xq/1000,zl,mask,cmap='Greys',vmin=0,vmax=2.)
ax1.set_xlabel('X Position (km)',fontsize=16); ax1.set_ylabel('Depth (m)',fontsize=16)
ax1.tick_params(labelsize=16); ax2.tick_params(labelsize=12);
orig_cmap = matplotlib.cm.RdBu_r
shifted_cmap = shiftedColorMap(orig_cmap, midpoint=0.25, name='shifted')
for i in range(190,241):
    vi=np.array(v[i,:,0,0:1280])
    vi[vi==0]=np.nan;
    quad1 = ax1.pcolormesh(xq/1000,zl,vi,cmap='shifted',vmin=-0.2,vmax=.6,shading='goaround')
    cb1 = fig.colorbar(quad1,ax2)
    ax1.set_title('Alongshore velocity (v), day=%05.2f ' %(i/4.), fontsize=14)
    ax2.set_title('m/s', fontsize=14)
    ax1.set_xlim(0,70)
    plt.savefig('index%.3d'%i)
# Out:
# /work2/eay/mitgcm_videos/gif2D
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-44ac090e492f> in <module>
#      19     ax2.set_title('m/s', fontsize=14)
#      20     ax1.set_xlim(0,70)
# ---> 21     plt.savefig('index%.3d'%i)
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /nbhome/eay/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py in draw(self, renderer)
#    2042                 gc, transform.frozen(), self._meshWidth, self._meshHeight,
#    2043                 coordinates, offsets, transOffset, self.get_facecolor(),
# -> 2044                 self._antialiased, self.get_edgecolors())
#    2045         gc.restore()
#    2046         renderer.close_group(self.__class__.__name__)
#
# KeyboardInterrupt:

# %%
# %cd /work/eay/mitgcm_videos/gif2D
#%rm *.png
fig = plt.figure(figsize=(16, 12), dpi= 80, facecolor='w', edgecolor='k')
ax1 = fig.add_axes([0.15,0.1,0.25,0.3])  #left pos. bottom pos. width, height #ax1 = fig.add_subplot(111)
ax2 = fig.add_axes([0.15,0.5,0.25,0.3])
ax3 = fig.add_axes([0.55,0.1,0.25,0.3])
ax4 = fig.add_axes([0.55,0.5,0.25,0.3])
cax1 = fig.add_axes([.45, 0.1, 0.03, 0.3])
cax2 = fig.add_axes([.45, 0.5, 0.03, 0.3])
cax1 = fig.add_axes([.85, 0.1, 0.03, 0.3])
cax2 = fig.add_axes([.85, 0.5, 0.03, 0.3])
#ax1.invert_yaxis

quad0= ax1.pcolormesh(xq/1000,zl,mask,cmap='Greys',vmin=0,vmax=2.)
quad0= ax2.pcolormesh(xq/1000,zl,mask,cmap='Greys',vmin=0,vmax=2.)
quad0= ax3.pcolormesh(xq/1000,zl,mask,cmap='Greys',vmin=0,vmax=2.)
quad4= ax4.pcolormesh(xq/1000,zl,mask,cmap='Greys',vmin=0,vmax=2.)

ax1.set_xlabel('X Position (km)',fontsize=16); ax3.set_xlabel('X Position (km)',fontsize=16); 
ax1.set_ylabel('Depth (m)',fontsize=16); ax2.set_ylabel('Depth (m)',fontsize=16)
#ax1.tick_params(labelsize=16); ax2.tick_params(labelsize=12);

for i in range(240,241):
    ui=np.array(u[i,:,0:1280])
    ui[ui==0]=np.nan;
    
    wi=np.array(w[i,:,0:1280])
    wi[wi==0]=np.nan;
       
    quad3 = ax3.pcolormesh(xq/1000,zl,ui,cmap='RdBu_r',vmin=-0.02,vmax=0.02,shading='goaround')
    quad4 = ax4.pcolormesh(xq/1000,zl,wi*1000,cmap='RdBu_r',vmin=-2,vmax=2,shading='goaround')
    #cb1 = fig.colorbar(quad1,axcolor)
    ax3.set_title('Offshore velocity (u), day=%05.2f ' %(i/4.), fontsize=14)
    ax4.set_title('Vertical velocity (w), day=%05.2f ' %(i/4.), fontsize=14)
    #axcolor.set_title('m/s', fontsize=14)
    ax1.set_xlim(0,70)
    ax2.set_xlim(0,70)
    ax3.set_xlim(0,70)
    ax4.set_xlim(0,70)
    
    plt.savefig('index%.3d'%i)
# Out:
# /work2/eay/mitgcm_videos/gif2D

# %%
fig,ax = plt.subplots(2,2)
for i in range(2) :
    for j in range(2) :
         data = np.array([[i,j],[i+0.5,j+0.5]])
         im = ax[i,j].imshow(data)
         plt.colorbar(im,ax=ax[i,j])

plt.show()
